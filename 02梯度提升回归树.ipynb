# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split


cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=0)

gbrt = GradientBoostingClassifier(random_state=0)
gbrt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=0, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
print(gbrt.score(X_train, y_train))
print(gbrt.score(X_test, y_test))
# Out:
# 1.0
# 0.958041958041958

# %%
gbrt_one = GradientBoostingClassifier(max_depth=1, random_state=0)
gbrt_one.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=0, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
print(gbrt_one.score(X_train, y_train))
print(gbrt_one.score(X_test, y_test))
# Out:
# 0.9906103286384976
# 0.972027972027972

# %%
gbrt_two = GradientBoostingClassifier(random_state=0, learning_rate=0.01)
gbrt_two.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.01, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=0, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
print(gbrt_two.score(X_train, y_train))
print(gbrt_two.score(X_test, y_test))
# Out:
# 0.9882629107981221
# 0.965034965034965

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_feature_importances_cancer(model):
    n_features = cancer.data.shape[1]
    plt.barh(range(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), cancer.feature_names)
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")

# %%
plot_feature_importances_cancer(gbrt_one)

# %%
plot_feature_importances_cancer(gbrt_two)
